# %%
# === 新版本：按 text_level 聚合 ===

import json
import re
from pathlib import Path
from typing import List, Dict, Any, Tuple, Optional
import pandas as pd
import fitz # PyMuPDF

# C:\Users\User\Desktop\Microsoft_GraphRAG\UnstructuredData_Transformation_Pipeline
# === Cell 1: Imports & Paths (可沿用) ===
DOC_CODE = "Advisory Guidelines on Key Concepts in the PDPA 17 May 2022"
INPUT_JSON = fr"C:\Users\User\Desktop\Compliance-GraphRAG\UnstructuredData_Transformation_Pipeline\out_md_mineru\{DOC_CODE}\hybrid_auto\{DOC_CODE}_content_list copy.json"
INPUT_PDF = fr"C:\Users\User\Desktop\Compliance-GraphRAG\UnstructuredData_Transformation_Pipeline\SPM\{DOC_CODE}.pdf"
DOC_ID = Path(INPUT_JSON).stem.split("_content_list")[0]
OUT_AGGREGATED_CSV = fr"C:\Users\User\Desktop\Compliance-GraphRAG\UnstructuredData_Transformation_Pipeline\SPM\csv_data\{DOC_ID}.csv"

# === Cell 2: Regex & Constants (沿用) ===
# HEADING_RE = re.compile(r'^\s*(\d+(?:\.\d+)*)[.\)]?\s+(.*\S)?\s*$')

# 新增邏輯：hybrid approach，結合 text_level 與 regex
HEADING_RE = re.compile(
    r'^\s*('
    r'\d+(?:\.\d+)*'             # 1. 原有的數字編號 (1.2, 3.4.5)
    r'|ANNEX\s+[A-Z0-9]+'        # 2. 新增: ANNEX 接數字或字母 (ANNEX 1, ANNEX A)
    r'|INTERPRETATIVE\s+NOTES'   # 3. 新增: 固定詞組 INTERPRETATIVE NOTES
    r')[:.\)]?(?:\s+(.*\S)?)?\s*$', # 4. 修改: 允許 ID 後面直接結束 (針對 standalone heading)
    re.IGNORECASE
)

HKMA_BANNER_KEYWORDS = ["monetary authority", "supervisory policy manual", "香港金融管理局"]
NAV_KEYWORDS = ["contents", "glossary", "home", "introduction"]
TOP_Y0_THRESHOLD = 100


# === Cell 3: Loaders & Basic Helpers (沿用) ===
def load_content_list(path: str) -> List[Dict[str, Any]]:
    p = Path(path)
    assert p.exists(), f"File not found: {path}"
    with open(p, "r", encoding="utf-8") as f:
        return json.load(f)

def bbox_is_top(bbox: List[int], y0_thr: int = TOP_Y0_THRESHOLD) -> bool:
    if not bbox or len(bbox) < 4: return False
    return bbox[1] <= y0_thr

def is_hkma_banner_table(block: Dict[str, Any]) -> bool:
    if block.get("type") != "table": return False
    if not bbox_is_top(block.get("bbox") or []): return False
    text_lc = (block.get("table_body") or "").lower()
    return any(kw in text_lc for kw in HKMA_BANNER_KEYWORDS)

def is_nav_table(block: Dict[str, Any]) -> bool:
    if block.get("type") != "table": return False
    table_body = (block.get("table_body") or "").lower()
    return any(kw in table_body for kw in NAV_KEYWORDS)

def normalize_text(s: Optional[str]) -> str:
    if not s: return ""
    return re.sub(r'\s+', ' ', s).strip()


# === Cell 4: Build Blocks (沿用) ===
def build_blocks(raw: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    cleaned = []
    for i, b in enumerate(raw):
        typ = b.get("type")
        if typ == "table" and (is_hkma_banner_table(b) or is_nav_table(b)):
            continue

        blk = {
            "type": typ, "page_idx": b.get("page_idx"), "bbox": b.get("bbox"),
            "text_level": b.get("text_level", None), "index": i,
        }
        if typ == "text":
            blk["text"] = normalize_text(b.get("text"))
        elif typ == "table":
            html = (b.get("table_body") or "").strip()
            blk["text"] = re.sub(r"\s+", " ", html)
        elif typ == "image":
            blk["text"] = "" # 圖片內容暫時忽略
        else:
            blk["text"] = normalize_text(b.get("text", ""))
        cleaned.append(blk)
    return cleaned


# === Cell 5: Heading Detection (沿用) ===
def classify_heading(text: str) -> Optional[Tuple[str, int, str]]:
    m = HEADING_RE.match(text)
    if not m: return None
    cid, title = m.group(1), m.group(2) or ""
    level = cid.count(".") + 1
    return (cid, level, title.strip())

# def find_headings(blocks: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
#     heads = []
#     for idx, b in enumerate(blocks):
#         if b["type"] != "text": continue
#         ch = classify_heading(b.get("text") or "")
#         if not ch: continue
#         clause_id, level, title = ch
#         heads.append({
#             "block_idx": idx, "clause_id": clause_id, "level": level,
#             "title": title, "page_idx": b.get("page_idx"), "bbox": b.get("bbox"),
#         })
#     return heads

def find_headings(blocks: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    heads = []
    print("--- Debugging Heading Detection (Strict Mode) ---")
    
    for idx, b in enumerate(blocks):
        if b["type"] != "text": continue
        
        text = b.get("text", "").strip()
        text_level = b.get("text_level")
        
        # 1. 檢查 Regex
        ch = classify_heading(text)
        
        # 2. 檢查 text_level
        is_level_one = (text_level == 1)
        
        # 3. 嚴格判定：必須兩者皆為真
        if ch and is_level_one:
            clause_id, level, title = ch
            print(f"[MATCH] Block {idx}: ID={clause_id} | Title={title[:30]}... | Level={level}")
            heads.append({
                "block_idx": idx, 
                "clause_id": clause_id, 
                "level": level,
                "title": title, 
                "page_idx": b.get("page_idx"), 
                "bbox": b.get("bbox"),
            })
        elif ch:
            # 這是符合 Regex 但 text_level 不是 1 的情況 (例如 2.1, 2.2)
            print(f"[SKIP - Low Level] Block {idx}: Matches Regex but text_level={text_level}. Text: {text[:50]}...")
        elif is_level_one:
            # 這是 text_level 為 1 但不符合 Regex 的情況 (例如 Annex, Glossary)
            print(f"[SKIP - No Regex] Block {idx}: text_level=1 but no Regex match. Text: {text[:50]}...")

    print(f"--- Total Headings Found: {len(heads)} ---")
    return heads

# === Cell 6: Slice bodies (MODIFIED) ===
def slice_body_with_tables(blocks: List[Dict[str, Any]], head_idx: int, next_head_idx: Optional[int]) -> Tuple[str, List[int], int, int]:
    start = head_idx + 1
    end = next_head_idx if next_head_idx is not None else len(blocks)
    content_parts = []
    body_indices = []
    page_start = blocks[head_idx].get("page_idx")
    page_end = page_start

    for i in range(start, end):
        b = blocks[i]
        # ✅ 修改點：現在包含 "text" 和 "table" 類型的 block
        if b["type"] in ("text", "table"):
            content = b.get("text") or ""
            if content.strip():
                content_parts.append(content.strip())
                body_indices.append(i)
                if b.get("page_idx") is not None:
                    page_end = b["page_idx"]

    body = "\n\n".join(content_parts).strip() # 用換兩行來分隔 block
    return body, body_indices, page_start, page_end

def choose_longest_by_id(candidates: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    best: Dict[str, Dict[str, Any]] = {}
    for c in candidates:
        cid = c["clause_id"]
        cur = best.get(cid)
        if (cur is None) or (c.get("body_len", 0) > cur.get("body_len", 0)):
            best[cid] = c
    return sorted(best.values(), key=lambda x: x.get("block_idx", 10**9))


# === Cell 7: Build Clause Rows (MODIFIED) ===
def parent_of(cid: str) -> Optional[str]:
    parts = cid.split(".")
    return ".".join(parts[:-1]) if len(parts) > 1 else None

def build_clause_rows(blocks: List[Dict[str, Any]], heads: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    rows = []
    for i, h in enumerate(heads):
        head_block_idx = h["block_idx"]
        next_block_idx = heads[i+1]["block_idx"] if i+1 < len(heads) else None
        
        heading_line = blocks[head_block_idx].get("text", "") or ""
        # ✅ 使用新的 slice 函式
        body_content, body_indices, page_start_idx, page_end_idx = slice_body_with_tables(blocks, head_block_idx, next_block_idx)

        full_text = (heading_line + "\n\n" + body_content).strip() if body_content else heading_line
        
        page_start = (page_start_idx or 0) + 1 if page_start_idx is not None else None
        page_end   = (page_end_idx or 0) + 1 if page_end_idx is not None else None

        rows.append({
            "document_id": DOC_ID, "clause_id": h["clause_id"], "level": h["level"],
            "parent_id": parent_of(h["clause_id"]), "title": h["title"],
            "heading_page": (h.get("page_idx") or 0) + 1 if h.get("page_idx") is not None else None,
            "heading_bbox": h.get("bbox"), "page_start": page_start, "page_end": page_end,
            "full_text": full_text, "body_len": len(full_text),
            "heading_block_idx": head_block_idx, "body_block_indices": body_indices,
            "block_idx": head_block_idx,
        })
        
    return choose_longest_by_id(rows)


# === Cell 8: Metadata Extraction (沿用) ===
def extract_pdf_metadata(pdf_path: Path) -> dict:
    pdf = fitz.open(str(pdf_path))
    md = pdf.metadata or {}
    pdf.close()
    return {"doc_title": md.get("title", ""), "author": md.get("author", "")}

def extract_json_metadata(json_path: Path) -> dict:
    with open(json_path, "r", encoding="utf-8") as f:
        raw_blocks = json.load(f)
    all_text = "\n".join(b.get("text", "") for b in raw_blocks if b.get("type") == "text")
    version = ""
    for b in raw_blocks:
        if is_hkma_banner_table(b):
            m = re.search(r'V\.\d+\s*[–\-]\s*\d{2}\.\d{2}\.\d{2,4}', b.get("table_body", ""))
            if m: version = m.group(0); break
    purpose = (re.search(r'Purpose\s*\n(.+)', all_text).group(1).strip() if re.search(r'Purpose\s*\n(.+)', all_text) else "")
    classification = (re.search(r'Classification\s*\n(.+)', all_text).group(1).strip() if re.search(r'Classification\s*\n(.+)', all_text) else "")
    previous_version = (re.search(r'Previous guidelines superseded\s*\n(.+)', all_text).group(1).strip() if re.search(r'Previous guidelines superseded\s*\n(.+)', all_text) else "")
    return {"version": version, "purpose": purpose, "classification": classification, "previous_version": previous_version}

def merge_metadata(pdf_path: Path, json_path: Path) -> dict:
    pdf_meta = extract_pdf_metadata(pdf_path)
    json_meta = extract_json_metadata(json_path)
    return {**pdf_meta, **json_meta}


# === Cell 9: Execution (MODIFIED) ===
# 1. 讀取與清理
raw = load_content_list(INPUT_JSON)
blocks = build_blocks(raw)

# 2. 尋找標題
heads = find_headings(blocks)
if not heads:
    raise RuntimeError("No numeric headings found. Check HEADING_RE or the input content.")
print(f"Found {len(heads)} headings.")

# 3. 組裝條款 (已包含表格)
clause_rows = build_clause_rows(blocks, heads)
print(f"Clauses after TOC-dedup (tables included): {len(clause_rows)}")

# 4. 排序
# def clause_sort_key(r: Dict[str, Any]):
#     parts = tuple(int(x) for x in r["clause_id"].split("."))
#     return (parts, r["level"])
# clause_rows_sorted = sorted(clause_rows, key=clause_sort_key)

clause_rows_sorted = sorted(clause_rows, key=lambda x: x["heading_block_idx"])

# 5. 匯出 CSV
df = pd.DataFrame(clause_rows_sorted)
if "body_block_indices" in df.columns:
    df["body_block_indices"] = df["body_block_indices"].apply(lambda x: "|".join(map(str, x)))
if "heading_bbox" in df.columns:
    df["heading_bbox"] = df["heading_bbox"].apply(lambda bb: ",".join(map(str, bb)) if bb else "")

# 6. 加入 Metadata
doc_metadata = merge_metadata(Path(INPUT_PDF), Path(INPUT_JSON))
for k, v in doc_metadata.items():
    df[k] = v

# 7. 整理欄位並儲存
cols = [
    "document_id", "clause_id", "level", "parent_id", "title", 
    "heading_page", "page_start", "page_end", "full_text", "body_len",
    "doc_title", "author", "version", "purpose", "classification", "previous_version",
    "heading_bbox", "heading_block_idx", "body_block_indices",
]
# 確保所有 metadata 欄位都存在
for col in cols:
    if col not in df.columns:
        df[col] = ""
df = df[cols]

df.to_csv(OUT_AGGREGATED_CSV, index=False, encoding="utf-8")
print(f"✅ Successfully saved merged data to: {OUT_AGGREGATED_CSV}")

display(df.head())
# Out:
# --- Debugging Heading Detection (Strict Mode) ---
# [SKIP - Low Level] Block 14: Matches Regex but text_level=None. Text: 6 Organisations...... ..22...
# [SKIP - Low Level] Block 54: Matches Regex but text_level=None. Text: 16 The Accuracy Obligation .. ..110...
# [SKIP - Low Level] Block 59: Matches Regex but text_level=None. Text: 17 The Protection Obligation ........ ....114...
# [SKIP - Low Level] Block 61: Matches Regex but text_level=None. Text: 18 The Retention Limitation Obligation..... ...117...
# [SKIP - Low Level] Block 66: Matches Regex but text_level=None. Text: 19 The Transfer Limitation Obligation ..... ..122...
# [SKIP - Low Level] Block 70: Matches Regex but text_level=None. Text: 20 The Data Breach Notification Obligation ..........
# [SKIP - Low Level] Block 78: Matches Regex but text_level=None. Text: 21 The Accountability Obligation ..... ....151...
# [SKIP - Low Level] Block 87: Matches Regex but text_level=None. Text: Annex A: Framework for the Collection, Use and Dis...
# [SKIP - Low Level] Block 88: Matches Regex but text_level=None. Text: Annex B: Assessment Checklist for Deemed Consent b...
# [SKIP - Low Level] Block 89: Matches Regex but text_level=None. Text: Annex C: Assessment Checklist for Legitimate Inter...
# [SKIP - No Regex] Block 92: text_level=1 but no Regex match. Text: PART I: INTRODUCTION AND OVERVIEW...
# [MATCH] Block 93: ID=1 | Title=Introduction... | Level=1
# [MATCH] Block 97: ID=2 | Title=Overview of the PDPA... | Level=1
# [SKIP - Low Level] Block 103: Matches Regex but text_level=None. Text: 2.5 Organisations have the following obligations i...
# [SKIP - No Regex] Block 108: text_level=1 but no Regex match. Text: PART II: IMPORTANT TERMS USED IN THE PDPA...
# [MATCH] Block 109: ID=3 | Title=Definitions and related matter... | Level=1
# [SKIP - Low Level] Block 112: Matches Regex but text_level=None. Text: 3.3 From the above statement of the PDPA’s purpose...
# [SKIP - Low Level] Block 114: Matches Regex but text_level=None. Text: 3.4 This section seeks to provide guidance on how ...
# [MATCH] Block 117: ID=4 | Title=Individuals... | Level=1
# [MATCH] Block 122: ID=5 | Title=Personal data... | Level=1
# [SKIP - Low Level] Block 123: Matches Regex but text_level=None. Text: 5.1 Personal data is defined in the PDPA as “data,...
# [SKIP - Low Level] Block 131: Matches Regex but text_level=None. Text: 5.6 A practical approach is to first identify the ...
# [SKIP - Low Level] Block 135: Matches Regex but text_level=None. Text: 5.9 Certain types of data, by their nature or use,...
# [SKIP - Low Level] Block 140: Matches Regex but text_level=None. Text: 5.10 The purpose of the dataset or document is ano...
# [SKIP - Low Level] Block 163: Matches Regex but text_level=None. Text: 5.13 Information about one individual may contain ...
# [SKIP - Low Level] Block 172: Matches Regex but text_level=None. Text: 5.16 For personal data about a deceased individual...
# [SKIP - Low Level] Block 180: Matches Regex but text_level=None. Text: 5.19...
# [SKIP - Low Level] Block 184: Matches Regex but text_level=None. Text: 5.20...
# [SKIP - No Regex] Block 190: text_level=1 but no Regex match. Text: Derived personal data...
# [SKIP - Low Level] Block 191: Matches Regex but text_level=None. Text: 5.21 Derived personal data is defined under the PD...
# [SKIP - Low Level] Block 204: Matches Regex but text_level=None. Text: 5.29 Similarly, if organisation A takes a photogra...
# [MATCH] Block 207: ID=6 | Title=Organisations... | Level=1
# [SKIP - Low Level] Block 210: Matches Regex but text_level=None. Text: 6.5 The PDPA provides that the Data Protection Pro...
# [SKIP - Low Level] Block 221: Matches Regex but text_level=None. Text: 6.11 The second significant exclusion for individu...
# [SKIP - Low Level] Block 224: Matches Regex but text_level=None. Text: 6.12 Notwithstanding this exclusion for employees,...
# [SKIP - Low Level] Block 226: Matches Regex but text_level=None. Text: 6.13 The PDPA defines a public agency to include t...
# [SKIP - Low Level] Block 228: Matches Regex but text_level=None. Text: 6.14 Public agencies are excluded from the applica...
# [SKIP - Low Level] Block 230: Matches Regex but text_level=None. Text: 6.15 The PDPA defines a data intermediary as “an o...
# [SKIP - Low Level] Block 237: Matches Regex but text_level=None. Text: 6.18 The term “processing” is defined in the PDPA ...
# [SKIP - Low Level] Block 239: Matches Regex but text_level=None. Text: 6.19 Items (a) to (g) above represent an indicativ...
# [SKIP - Low Level] Block 259: Matches Regex but text_level=None. Text: 6.27 Where Organisation B is a data intermediary o...
# [SKIP - Low Level] Block 268: Matches Regex but text_level=None. Text: 6.28 It is possible for an organisation that is pa...
# [SKIP - Low Level] Block 271: Matches Regex but text_level=None. Text: 6.29 An organisation can be considered a data inte...
# [SKIP - Low Level] Block 275: Matches Regex but text_level=None. Text: 6.30 In relation to network service providers, the...
# [MATCH] Block 283: ID=7 | Title=Collection, Use and Disclosure... | Level=1
# [SKIP - Low Level] Block 286: Matches Regex but text_level=None. Text: 7.3 Organisations should bear in mind that collect...
# [MATCH] Block 292: ID=8 | Title=Purposes... | Level=1
# [MATCH] Block 298: ID=9 | Title=Reasonableness... | Level=1
# [SKIP - No Regex] Block 302: text_level=1 but no Regex match. Text: PART III: THE DATA PROTECTION PROVISIONS...
# [MATCH] Block 303: ID=10 | Title=Overview of the Data Protectio... | Level=1
# [SKIP - Low Level] Block 311: Matches Regex but text_level=None. Text: 10.3 Some of the ten obligations mentioned above m...
# [MATCH] Block 314: ID=11 | Title=Applicability to Inbound Data ... | Level=1
# [SKIP - Low Level] Block 315: Matches Regex but text_level=None. Text: 11.1 The Data Protection Provisions apply to organ...
# [SKIP - Low Level] Block 319: Matches Regex but text_level=None. Text: 11.2 Where personal data originating from outside ...
# [SKIP - Low Level] Block 323: Matches Regex but text_level=None. Text: 11.3 Where personal data collected from outside Si...
# [MATCH] Block 326: ID=12 | Title=The Consent Obligation... | Level=1
# [SKIP - Low Level] Block 340: Matches Regex but text_level=None. Text: 12.8 Section 14(4) of the PDPA provides that conse...
# [SKIP - Low Level] Block 345: Matches Regex but text_level=None. Text: 12.9 In order to obtain consent from a person vali...
# [SKIP - Low Level] Block 360: Matches Regex but text_level=None. Text: 12.17 Section 14(2)(b) addresses the situation whe...
# [SKIP - Low Level] Block 439: Matches Regex but text_level=None. Text: 12.29 There are two situations in which organisati...
# [SKIP - Low Level] Block 460: Matches Regex but text_level=None. Text: 12.37 As consent of the individual is not required...
# [SKIP - Low Level] Block 508: Matches Regex but text_level=None. Text: 12.51 Consequences for withdrawal of consent could...
# [SKIP - Low Level] Block 525: Matches Regex but text_level=None. Text: 12.56 “Legitimate interests” generally refer to an...
# [SKIP - Low Level] Block 536: Matches Regex but text_level=None. Text: 12.59 Organisations cannot rely on the legitimate ...
# [SKIP - Low Level] Block 546: Matches Regex but text_level=None. Text: 12.63 Examples of legitimate interests include the...
# [SKIP - Low Level] Block 612: Matches Regex but text_level=None. Text: 12.77 Organisations cannot rely on the business im...
# [SKIP - Low Level] Block 653: Matches Regex but text_level=None. Text: 12.83 The Commission considers the degree of pract...
# [SKIP - Low Level] Block 655: Matches Regex but text_level=None. Text: 12.84 Another significant exception in paragraph 1...
# [SKIP - Low Level] Block 668: Matches Regex but text_level=None. Text: 12.90 Personal data is observed by reasonably expe...
# [MATCH] Block 687: ID=13 | Title=The Purpose Limitation Obligat... | Level=1
# [SKIP - Low Level] Block 688: Matches Regex but text_level=None. Text: 13.1 Section 18 of the PDPA limits the purposes fo...
# [MATCH] Block 698: ID=14 | Title=The Notification Obligation... | Level=1
# [SKIP - Low Level] Block 703: Matches Regex but text_level=None. Text: 14.5 It is important for an organisation to identi...
# [SKIP - Low Level] Block 706: Matches Regex but text_level=None. Text: 14.6 The following paragraphs consider three impor...
# [SKIP - Low Level] Block 716: Matches Regex but text_level=None. Text: 14.11 It is generally good practice for an organis...
# [SKIP - Low Level] Block 724: Matches Regex but text_level=None. Text: 14.14 For the avoidance of doubt, organisations ar...
# [SKIP - Low Level] Block 737: Matches Regex but text_level=None. Text: 14.17 Informing the individual of the purposes for...
# [MATCH] Block 758: ID=15 | Title=The Access and Correction Obli... | Level=1
# [SKIP - Low Level] Block 761: Matches Regex but text_level=None. Text: 15.3 Section 21(1) of the PDPA provides that, upon...
# [SKIP - Low Level] Block 768: Matches Regex but text_level=None. Text: 15.4 Section 21(1) allows an individual to submit ...
# [SKIP - Low Level] Block 778: Matches Regex but text_level=None. Text: 15.11 The PDPA does not expressly state that an ac...
# [SKIP - Low Level] Block 782: Matches Regex but text_level=None. Text: 15.12 Before responding to an access request, orga...
# [SKIP - Low Level] Block 783: Matches Regex but text_level=None. Text: 15.13 In a situation where a third party is making...
# [SKIP - Low Level] Block 784: Matches Regex but text_level=None. Text: 15.14 In some cases, there may be two or more indi...
# [SKIP - Low Level] Block 793: Matches Regex but text_level=None. Text: 15.15 As stated in section 21(1) of the PDPA, if a...
# [SKIP - Low Level] Block 800: Matches Regex but text_level=None. Text: 15.18 Subject to the PDPA and the Personal Data Pr...
# [SKIP - Low Level] Block 816: Matches Regex but text_level=None. Text: 15.27 If an organisation wishes to charge an indiv...
# [SKIP - Low Level] Block 827: Matches Regex but text_level=None. Text: 15.30 The exceptions specified in the Fifth Schedu...
# [SKIP - Low Level] Block 858: Matches Regex but text_level=None. Text: 15.33 Section 21(5) of the PDPA provides that if a...
# [SKIP - Low Level] Block 868: Matches Regex but text_level=None. Text: 15.34 One of the prohibitions, section 21(3)(c), r...
# [SKIP - Low Level] Block 891: Matches Regex but text_level=None. Text: 15.35 Section 21(4) of the PDPA contains an additi...
# [SKIP - Low Level] Block 893: Matches Regex but text_level=None. Text: 15.36 Where personal data has been collected for t...
# [SKIP - Low Level] Block 898: Matches Regex but text_level=None. Text: 15.37 Where personal data has been collected prior...
# [SKIP - Low Level] Block 900: Matches Regex but text_level=None. Text: 15.38 Subject to the PDPA and the Personal Data Pr...
# [SKIP - Low Level] Block 917: Matches Regex but text_level=None. Text: 15.45 Section 22(1) of the PDPA provides that an i...
# [SKIP - Low Level] Block 928: Matches Regex but text_level=None. Text: 15.50 If an organisation is satisfied upon reasona...
# [SKIP - Low Level] Block 930: Matches Regex but text_level=None. Text: 15.51 Section 22(6) provides that an organisation ...
# [SKIP - Low Level] Block 937: Matches Regex but text_level=None. Text: 15.52 Subject to exceptions as described above, an...
# [MATCH] Block 951: ID=16 | Title=The Accuracy Obligation... | Level=1
# [SKIP - Low Level] Block 952: Matches Regex but text_level=None. Text: 16.1 Section 23 of the PDPA requires an organisati...
# [SKIP - Low Level] Block 957: Matches Regex but text_level=None. Text: 16.4 The Accuracy Obligation requires organisation...
# [SKIP - Low Level] Block 962: Matches Regex but text_level=None. Text: 16.5 For the avoidance of doubt, an organisation m...
# [SKIP - Low Level] Block 964: Matches Regex but text_level=None. Text: 16.6 Organisations may presume that personal data ...
# [SKIP - Low Level] Block 971: Matches Regex but text_level=None. Text: 16.7 An organisation should also be more careful w...
# [SKIP - Low Level] Block 977: Matches Regex but text_level=None. Text: 16.8 Similar considerations apply when deciding wh...
# [SKIP - Low Level] Block 982: Matches Regex but text_level=None. Text: 16.9 The Commission recognises that organisations ...
# [MATCH] Block 985: ID=17 | Title=The Protection Obligation... | Level=1
# [SKIP - Low Level] Block 988: Matches Regex but text_level=None. Text: 17.4 In addition, it might be useful for organisat...
# [SKIP - Low Level] Block 994: Matches Regex but text_level=None. Text: 17.5 Security arrangements may take various forms ...
# [MATCH] Block 1006: ID=18 | Title=The Retention Limitation Oblig... | Level=1
# [SKIP - Low Level] Block 1007: Matches Regex but text_level=None. Text: 18.1 Section 25 of the PDPA requires an organisati...
# [SKIP - Low Level] Block 1032: Matches Regex but text_level=None. Text: 18.13 In considering whether an organisation has c...
# [SKIP - Low Level] Block 1038: Matches Regex but text_level=None. Text: 18.14 An organisation will be considered to have c...
# [MATCH] Block 1041: ID=19 | Title=The Transfer Limitation Obliga... | Level=1
# [SKIP - Low Level] Block 1049: Matches Regex but text_level=None. Text: 19.6 Second, if the recipient organisation holds a...
# [SKIP - Low Level] Block 1058: Matches Regex but text_level=None. Text: 19.7 Organisations are encouraged to rely on legal...
# [SKIP - Low Level] Block 1060: Matches Regex but text_level=None. Text: 19.8 The examples below illustrate certain situati...
# [SKIP - Low Level] Block 1098: Matches Regex but text_level=None. Text: 19.9 In setting out contractual clauses that requi...
# [SKIP - Low Level] Block 1104: Matches Regex but text_level=None. Text: 19.10 The above table reflects the position under ...
# [SKIP - Low Level] Block 1106: Matches Regex but text_level=None. Text: 19.11 Data in transit refers to personal data tran...
# [MATCH] Block 1110: ID=20 | Title=The Data Breach Notification O... | Level=1
# [SKIP - Low Level] Block 1111: Matches Regex but text_level=None. Text: 20.1 Part 6A of the PDPA sets out the requirements...
# [SKIP - Low Level] Block 1115: Matches Regex but text_level=None. Text: 20.6 A data breach that relates to the unauthorise...
# [SKIP - Low Level] Block 1224: Matches Regex but text_level=None. Text: 20.16 The prescribed personal data or classes of p...
# [SKIP - Low Level] Block 1241: Matches Regex but text_level=None. Text: 20.19 Data breaches of a significant scale may ind...
# [SKIP - Low Level] Block 1259: Matches Regex but text_level=None. Text: 20.22 Upon determining that a data breach is notif...
# [SKIP - Low Level] Block 1263: Matches Regex but text_level=None. Text: 20.26 Section 26D of the PDPA provides for excepti...
# [SKIP - Low Level] Block 1267: Matches Regex but text_level=None. Text: 20.27 Where an exception applies to a data breach ...
# [SKIP - Low Level] Block 1294: Matches Regex but text_level=None. Text: 20.35 Where organisations are required to notify a...
# [SKIP - Low Level] Block 1299: Matches Regex but text_level=None. Text: 20.36 Where there is no regular mode of communicat...
# [SKIP - Low Level] Block 1305: Matches Regex but text_level=None. Text: 20.37 An organisation notifying affected individua...
# [SKIP - Low Level] Block 1310: Matches Regex but text_level=None. Text: 20.38 To ensure proactive steps are taken by the o...
# [SKIP - Low Level] Block 1336: Matches Regex but text_level=None. Text: 20.45 Organisations may customise their notificati...
# [SKIP - Low Level] Block 1338: Matches Regex but text_level=None. Text: 20.46 Where an organisation is required to notify ...
# [MATCH] Block 1341: ID=21 | Title=The Accountability Obligation8... | Level=1
# [SKIP - Low Level] Block 1344: Matches Regex but text_level=None. Text: 21.3 Section 11(3) of the PDPA requires an organis...
# [SKIP - Low Level] Block 1355: Matches Regex but text_level=None. Text: 21.7 The business contact information of the relev...
# [SKIP - Low Level] Block 1368: Matches Regex but text_level=None. Text: 21.14 The Data Protection Provisions also provide ...
# [SKIP - Low Level] Block 1377: Matches Regex but text_level=None. Text: 21.15 Although not expressly provided for in the P...
# [SKIP - No Regex] Block 1385: text_level=1 but no Regex match. Text: PART IV: OFFENCES AFFECTING PERSONAL DATA AND ANON...
# [MATCH] Block 1386: ID=22 | Title=Overview... | Level=1
# [SKIP - Low Level] Block 1387: Matches Regex but text_level=None. Text: 22.1 Offences under Part 9B of the PDPA hold indiv...
# [MATCH] Block 1391: ID=23 | Title=Offences for egregious mishand... | Level=1
# [SKIP - Low Level] Block 1392: Matches Regex but text_level=None. Text: 23.1 These offences do not detract from the policy...
# [SKIP - Low Level] Block 1394: Matches Regex but text_level=None. Text: 23.2 These offences are not intended to cover inst...
# [SKIP - Low Level] Block 1397: Matches Regex but text_level=None. Text: 23.3 The PDPA provides for the following defences ...
# [SKIP - Low Level] Block 1404: Matches Regex but text_level=None. Text: 23.4 Part 4A of the Personal Data Protection Regul...
# [SKIP - Low Level] Block 1406: Matches Regex but text_level=None. Text: 23.5 For the offence outlined in paragraph 22.1(c)...
# [SKIP - Low Level] Block 1413: Matches Regex but text_level=None. Text: 23.6 As such, these additional defences may be app...
# [SKIP - No Regex] Block 1417: text_level=1 but no Regex match. Text: PART V: OTHER RIGHTS, OBLIGATIONS AND USES...
# [MATCH] Block 1418: ID=24 | Title=Overview... | Level=1
# [SKIP - Low Level] Block 1421: Matches Regex but text_level=None. Text: 24.3 Each of the above is considered in greater de...
# [MATCH] Block 1424: ID=25 | Title=Rights and obligations, etc. u... | Level=1
# [MATCH] Block 1437: ID=26 | Title=Use of personal data collected... | Level=1
# [SKIP - Low Level] Block 1450: Matches Regex but text_level=None. Text: 26.6 An organisation can use personal data under s...
# --- Total Headings Found: 26 ---
# Found 26 headings.
# Clauses after TOC-dedup (tables included): 26
# ✅ Successfully saved merged data to: C:\Users\User\Desktop\Compliance-GraphRAG\UnstructuredData_Transformation_Pipeline\SPM\csv_data\Advisory Guidelines on Key Concepts in the PDPA 17 May 2022.csv
#                                          document_id clause_id  level  \
# 0  Advisory Guidelines on Key Concepts in the PDP...         1      1
# 1  Advisory Guidelines on Key Concepts in the PDP...         2      1
# 2  Advisory Guidelines on Key Concepts in the PDP...         3      1
# 3  Advisory Guidelines on Key Concepts in the PDP...         4      1
# 4  Advisory Guidelines on Key Concepts in the PDP...         5      1
#
#   parent_id                            title  heading_page  page_start  \
# 0      None                     Introduction             7           7
# 1      None             Overview of the PDPA             8           8
# 2      None  Definitions and related matters            10          10
# 3      None                      Individuals            11          11
# 4      None                    Personal data            12          12
#
#    page_end                                          full_text  body_len  \
# 0         7                                     1 Introduction        14
# 1        10  2 Overview of the PDPA\n\n2.5 Organisations ha...       197
# 2        10  3 Definitions and related matters\n\n“The purp...       654
# 3        11                                      4 Individuals        13
# 4        21  5 Personal data\n\n5.1 Personal data is define...     11278
#
#   doc_title author version purpose classification previous_version  \
# 0
# 1
# 2
# 3
# 4
#
#       heading_bbox  heading_block_idx  \
# 0  115,124,315,141                 93
# 1   115,86,410,104                 97
# 2  115,124,500,141                109
# 3   115,86,299,103                117
# 4   115,86,327,104                122
#
#                                   body_block_indices
# 0
# 1                                            103|108
# 2                                        111|112|114
# 3
# 4  123|126|130|131|132|134|135|138|139|140|142|14...
